# %%
import pandas as pd

# %%
df = pd.read_csv("loan_approval_dataset.csv")
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df[" loan_status"].unique()
# Out:
# <StringArray>
# [' Approved', ' Rejected']
# Length: 2, dtype: str

# %%
df.columns = df.columns.str.strip()
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip()
# Out:
# C:\Users\klebc\AppData\Local\Temp\ipykernel_1424\1900561521.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df.select_dtypes(include='object').columns:

# %%
df.drop(columns=['loan_id'], inplace=True)

# %%
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000     29900000
# 1                 0  Not Graduate           Yes       4100000     12200000
# 2                 3      Graduate            No       9100000     29700000
# 3                 3      Graduate            No       8200000     30700000
# 4                 5  Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value loan_status
# 0             22700000           8000000    Approved
# 1              8800000           3300000    Rejected
# 2             33300000          12800000    Rejected
# 3             23300000           7900000    Rejected
# 4             29400000           5000000    Rejected

# %%
df.isnull().sum()
# Out:
# no_of_dependents            0
# education                   0
# self_employed               0
# income_annum                0
# loan_amount                 0
# loan_term                   0
# cibil_score                 0
# residential_assets_value    0
# commercial_assets_value     0
# luxury_assets_value         0
# bank_asset_value            0
# loan_status                 0
# dtype: int64

# %%
df['loan_status'] = df['loan_status'].map({
    "Approved": 0,
    "Rejected": 1
})

# %%
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000     29900000
# 1                 0  Not Graduate           Yes       4100000     12200000
# 2                 3      Graduate            No       9100000     29700000
# 3                 3      Graduate            No       8200000     30700000
# 4                 5  Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value  loan_status
# 0             22700000           8000000            0
# 1              8800000           3300000            1
# 2             33300000          12800000            1
# 3             23300000           7900000            1
# 4             29400000           5000000            1

# %%
x = df.drop("loan_status", axis=1)
y = df["loan_status"]

# %%
df.head()
# Out:
#    no_of_dependents     education self_employed  income_annum  loan_amount  \
# 0                 2      Graduate            No       9600000     29900000
# 1                 0  Not Graduate           Yes       4100000     12200000
# 2                 3      Graduate            No       9100000     29700000
# 3                 3      Graduate            No       8200000     30700000
# 4                 5  Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value  loan_status
# 0             22700000           8000000            0
# 1              8800000           3300000            1
# 2             33300000          12800000            1
# 3             23300000           7900000            1
# 4             29400000           5000000            1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   no_of_dependents          4269 non-null   int64
#  1   education                 4269 non-null   str
#  2   self_employed             4269 non-null   str
#  3   income_annum              4269 non-null   int64
#  4   loan_amount               4269 non-null   int64
#  5   loan_term                 4269 non-null   int64
#  6   cibil_score               4269 non-null   int64
#  7   residential_assets_value  4269 non-null   int64
#  8   commercial_assets_value   4269 non-null   int64
#  9   luxury_assets_value       4269 non-null   int64
#  10  bank_asset_value          4269 non-null   int64
#  11  loan_status               4269 non-null   int64
# dtypes: int64(10), str(2)
# memory usage: 400.3 KB

# %%
df.shape
# Out:
# (4269, 12)

# %%
df["loan_status"].value_counts(normalize=True)
# Out:
# loan_status
# 0    0.62216
# 1    0.37784
# Name: proportion, dtype: float64

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2,random_state=42, stratify=y
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipe_lr = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(max_iter=1000))
])

# %%
pipe_rf = Pipeline([
    ('model', RandomForestClassifier(random_state=42))
    
])

# %%
pipe_gb = Pipeline([
    ('model', GradientBoostingClassifier(random_state=42))
    
])

# %%
pipe_lr.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', LogisticRegression(max_iter=1000))])

# %%
pipe_rf.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('model', RandomForestClassifier(random_state=42))])

# %%
pipe_gb.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('model', GradientBoostingClassifier(random_state=42))])

# %%
from sklearn.metrics import accuracy_score
models = {
    "Logistic Regression": pipe_lr,
    "Random Forest": pipe_rf,
    "Gradient Boosting": pipe_gb
}
for name, model in models.items():
    y_pred = model.predict(x_test)
    acc = accuracy_score(y_test,y_pred)
    print(f"{name} Accuracy: {acc:4f}")
# Out:
# Logistic Regression Accuracy: 0.922717
# Random Forest Accuracy: 0.981265
# Gradient Boosting Accuracy: 0.982436

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, pipe_gb.predict(x_test))

sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
x.shape
# Out:
# (4269, 11)

# %%
importances =  pipe_gb.named_steps["model"].feature_importances_
features = x.columns

importances_df = pd.DataFrame({
    "Feature": features,
    "Importance": importances,
}).sort_values(by="Importance", ascending=False)

importances_df.head(10)
# Out:
#                      Feature  Importance
# 4                cibil_score    0.868054
# 3                  loan_term    0.096636
# 2                loan_amount    0.017181
# 1               income_annum    0.007030
# 7        luxury_assets_value    0.004406
# 8           bank_asset_value    0.002006
# 6    commercial_assets_value    0.002002
# 5   residential_assets_value    0.001970
# 0           no_of_dependents    0.000612
# 10         self_employed_Yes    0.000103

# %%
from sklearn.pipeline import Pipeline
import pickle
Pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', GradientBoostingClassifier())
])

Pipeline.fit(x_train, y_train)

pickle.dump(Pipeline, open("loan_model.pkl", "wb"))
